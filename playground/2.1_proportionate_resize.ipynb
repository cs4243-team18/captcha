# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from helper_functions.segmentation import segment_by_projection_v1_proportionate, segment_by_projection_v1
from helper_functions.preprocessing import preprocess_image_v1
from helper_functions.data_transformation import _get_resized_img
PROJECTION_THRESHOLD = 0.1

filename = '0wwhwf-0.png'
img_path = '../data/train/combine2/0wwhwf-0.png'
filename_without_suffix = os.path.splitext(filename)[0]
correct_characters = filename_without_suffix.split('-')[0]
image = cv2.imread(img_path)
preprocessed_image = preprocess_image_v1(image)
plt.imshow(preprocessed_image)
plt.show()
char_imgs = segment_by_projection_v1([preprocessed_image])[0]
char_imgs_proportionate = segment_by_projection_v1_proportionate([preprocessed_image])[0]
for image1, image2 in zip(char_imgs_proportionate, char_imgs):
    plt.figure(figsize=(8, 4))
    plt.subplot(1, 2, 1)
    plt.imshow(image1)
    plt.subplot(1, 2, 2)
    plt.imshow(image2)
    plt.tight_layout()
    plt.show()
    print(image1.shape, image2.shape)
# Out:
# c:\Users\ongka\scoop\apps\python\current\lib\site-packages\torch\utils\_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# (40, 29) (56, 17)
# (40, 30) (56, 16)
# (40, 30) (56, 16)
# (40, 30) (56, 17)
# (39, 30) (56, 18)
# (40, 30) (56, 18)
